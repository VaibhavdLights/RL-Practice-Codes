# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("metric.csv")

# %%
df.tail(1)
# Out:
#    episode  length  total_reward     avg_q  exploration
# 9        9    1000    -60.526316  0.096131     0.956105

# %%
df.head()
# Out:
#    episode  length  total_reward     avg_q  exploration
# 0        0    1000    -66.867470  0.503723     1.000000
# 1        1    1000    -62.732919  0.437029     0.995025
# 2        2    1000    -45.848375  0.373029     0.990075
# 3        3    1000    -57.597173  0.182089     0.985149
# 4        4    1000    -61.194030  0.160308     0.980248

# %%
for col in df.columns[1:]:
    plt.figure()
    plt.plot(df[col])
    plt.title(col)
    plt.show()
