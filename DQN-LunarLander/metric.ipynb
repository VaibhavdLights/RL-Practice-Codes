# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("metric.csv")

# %%
df.tail(1)
# Out:
#      episode  length  total_reward      avg_q  exploration
# 599      599     245     -23.48583  87.884483     0.050411

# %%
df.head()
# Out:
#    episode  length  total_reward     avg_q  exploration
# 0        0     122   -191.749768 -0.060159     1.000000
# 1        1      61    -95.936310  0.132575     0.995025
# 2        2     121   -151.823542  0.008627     0.990075
# 3        3      90   -112.453287 -0.279482     0.985149
# 4        4     120   -374.649643 -0.666169     0.980248

# %%
for col in df.columns[1:]:
    plt.figure()
    plt.plot(df[col])
    plt.title(col)
    plt.show()
