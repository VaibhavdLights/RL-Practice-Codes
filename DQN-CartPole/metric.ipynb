# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("metric.csv")

# %%
df.tail(1)
# Out:
#      episode  length  total_reward       avg_q  exploration
# 399      399      95         -93.0  303.695221     0.136691

# %%
df.head()
# Out:
#    episode  length  total_reward     avg_q  exploration
# 0        0      18          -8.0  0.006996     1.000000
# 1        1       9          -7.0  0.006996     0.995025
# 2        2      15          -7.0  0.006996     0.990075
# 3        3      29           5.0 -0.012469     0.985149
# 4        4      19          -1.0 -0.074147     0.980248

# %%
for col in df.columns[1:]:
    plt.figure()
    plt.plot(df[col])
    plt.title(col)
    plt.show()
