# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("metric.csv")

# %%
df.tail(1)
# Out:
#      episode  length  total_reward      avg_q  exploration
# 399      399     501         345.0  63.691292     0.136691

# %%
df.head()
# Out:
#    episode  length  total_reward     avg_q  exploration
# 0        0      29           9.0  0.226818     1.000000
# 1        1      19          -3.0  0.226818     0.995025
# 2        2      14          -4.0  0.226818     0.990075
# 3        3      28           0.0  0.264931     0.985149
# 4        4      27          -5.0  0.300812     0.980248

# %%
for col in df.columns[1:]:
    plt.figure()
    plt.plot(df[col])
    plt.title(col)
    plt.show()
