# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("metric.csv")

# %%
df.tail(1)
# Out:
#       episode  length  total_reward      avg_q  exploration
# 1499     1499     117        -117.0 -75.322838     0.000566

# %%
df.head()
# Out:
#    episode  length  total_reward      avg_q  exploration
# 0        0   36912      -36912.0 -30.896570     1.000000
# 1        1   15608      -15608.0 -40.704617     0.995025
# 2        2   18556      -18556.0 -50.923561     0.990075
# 3        3   28664      -28664.0 -62.673939     0.985149
# 4        4   67516      -67516.0 -79.742958     0.980248

# %%
for col in df.columns[1:]:
    plt.figure()
    plt.plot(df[col])
    plt.title(col)
    plt.show()
